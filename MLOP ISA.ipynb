# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# If an encoding error occurs, try reading with ISO-8859-1 encoding( a character encoding that covers a large set of characters from various languages)
df = pd.read_csv('dsn.csv', encoding='ISO-8859-1')

# Display the DataFrame
print(df)
# Out:
#     Day of Week                                Director   Genre  \
# 0        Friday                               Brad Bird  action
# 1        Friday                             Scott Waugh  action
# 2        Friday                          Patrick Hughes  action
# 3        Friday                 Phil Lord, Chris Miller  comedy
# 4        Friday                         Roland Emmerich  action
# ..          ...                                     ...     ...
# 603   Wednesday                        William Friedkin  horror
# 604   Wednesday                            George Lucas  action
# 605      Friday                           James Cameron  sci-fi
# 606   Wednesday                           James Cameron   drama
# 607      Friday  George Cukor, Victor Fleming, Sam Wood   drama
#
#             Movie Title Release Date               Studio  \
# 0          Tomorrowland   22-05-2015  Buena Vista Studios
# 1        Need for Speed   14-03-2014  Buena Vista Studios
# ...

# %%
df.head(5)
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22-05-2015  Buena Vista Studios                  202.1           170.0
# 1   14-03-2014  Buena Vista Studios                  204.2            66.0
# 2   15-08-2014            Lionsgate                  207.1           100.0
# 3   16-03-2012                 Sony                  208.8            42.0
# 4   28-06-2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
df.tail(10)
# Out:
#     Day of Week                                           Director      Genre  \
# 598      Friday                                   Steven Spielberg  adventure
# 599   Wednesday  Wolfgang Reitherman, Clyde Geronimi, Hamilton ...  animation
# 600      Friday                                   Steven Spielberg  adventure
# 601      Friday                                   Steven Spielberg   thriller
# 602     Tuesday                                  Richard Fleischer  adventure
# 603   Wednesday                                   William Friedkin     horror
# 604   Wednesday                                       George Lucas     action
# 605      Friday                                      James Cameron     sci-fi
# 606   Wednesday                                      James Cameron      drama
# 607      Friday             George Cukor, Victor Fleming, Sam Wood      drama
#
#                      Movie Title Release Date              Studio  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Day of Week             608 non-null    object
#  1   Director                608 non-null    object
#  2   Genre                   608 non-null    object
#  3   Movie Title             608 non-null    object
#  4   Release Date            608 non-null    object
#  5   Studio                  608 non-null    object
#  6   Adjusted Gross ($mill)  608 non-null    object
#  7   Budget ($mill)          608 non-null    float64
#  8   Gross ($mill)           608 non-null    object
#  9   IMDb Rating             608 non-null    float64
#  10  MovieLens Rating        608 non-null    float64
#  11  Overseas ($mill)        608 non-null    object
#  12  Overseas%               608 non-null    float64
#  13  Profit ($mill)          608 non-null    object
# ...

# %%
df.shape
# Out:
# (608, 18)

# %%
df.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Budget ($mill)  IMDb Rating  MovieLens Rating   Overseas%  \
# count      608.000000   608.000000        608.000000  608.000000
# mean        92.467928     6.923849          3.340378   57.698849
# std         59.421407     0.925890          0.454071   12.334237
# min          0.600000     3.600000          1.490000   17.200000
# 25%         45.000000     6.375000          3.037500   49.900000
# 50%         80.000000     6.900000          3.365000   58.200000
# 75%        130.000000     7.600000          3.672500   66.300000
# max        300.000000     9.200000          4.500000  100.000000
#
#             Profit%  Runtime (min)  US ($mill)  Gross % US
# count    608.000000     608.000000  608.000000  608.000000
# mean     719.278783     117.781250  167.135197   42.301151
# std     1942.807248      23.179122   92.465903   12.334237
# min        7.700000      30.000000    0.000000    0.000000
# 25%      201.850000     100.000000  106.950000   33.700000
# ...

# %%
df.isnull().sum()
# Out:
# Day of Week               0
# Director                  0
# Genre                     0
# Movie Title               0
# Release Date              0
# Studio                    0
# Adjusted Gross ($mill)    0
# Budget ($mill)            0
# Gross ($mill)             0
# IMDb Rating               0
# MovieLens Rating          0
# Overseas ($mill)          0
# Overseas%                 0
# Profit ($mill)            0
# Profit%                   0
# Runtime (min)             0
# US ($mill)                0
# Gross % US                0
# dtype: int64

# %%
#features unique value
for column in df.columns:
    print(column,df[column].nunique())
# Out:
# Day of Week 6
# Director 337
# Genre 15
# Movie Title 608
# Release Date 534
# Studio 36
# Adjusted Gross ($mill) 585
# Budget ($mill) 152
# Gross ($mill) 561
# IMDb Rating 50
# MovieLens Rating 182
# Overseas ($mill) 551
# Overseas% 328
# Profit ($mill) 566
# Profit% 589
# Runtime (min) 102
# US ($mill) 535
# Gross % US 328

# %%
categorical_columns = df.select_dtypes(include=['object']).columns

# Print the categorical columns
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Gross ($mill)', 'Overseas ($mill)',
#        'Profit ($mill)'],
#       dtype='object')

# %%
numerical_columns = df.select_dtypes(include=['number']).columns

# Print the numerical columns
print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# Index(['Budget ($mill)', 'IMDb Rating', 'MovieLens Rating', 'Overseas%',
#        'Profit%', 'Runtime (min)', 'US ($mill)', 'Gross % US'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))
sns.set(style="whitegrid")  # Set the style of the plot

# Create a grid layout
rows = (len(numerical_columns) + 2) // 3
fig, axes = plt.subplots(rows, 3, figsize=(15, 5 * rows))


axes = axes.flatten()

# Plot each numerical feature with outliers
for i, feature in enumerate(numerical_columns):
    sns.boxplot(x=df[feature], ax=axes[i], color='skyblue', showfliers=True)
    axes[i].set_title(f'Box Plot for {feature}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'numerical_columns' is a list of columns with outliers
numerical_columns = ['Budget ($mill)', 'IMDb Rating', 'MovieLens Rating', 'Overseas%',
       'Profit%', 'Runtime (min)', 'US ($mill)', 'Gross % US']
# Create a copy of the original DataFrame to keep the original data intact
df_no_outliers = df.copy()

# Loop through each numerical column and remove outliers
for feature in numerical_columns:
    q1 = df_no_outliers['Profit%'].quantile(0.25)
    q3 = df_no_outliers['US ($mill)'].quantile(0.75)
    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Remove outliers for the current column
print(f"Lower Bound for {feature}: {lower_bound}")
print(f"Upper Bound for {feature}: {upper_bound}")
# Out:
# Lower Bound for Gross % US: 201.475
# Upper Bound for Gross % US: 202.475

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Genre', y='Gross % US', data=df, palette='Set3')

# Add labels and title
plt.xlabel('Genre')
plt.ylabel('Gross % US')
plt.title('Box Plot: Genre vs Gross % US')

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Genre', y='Gross % US', data=df, palette='Set3')
sns.swarmplot(x='Genre', y='Gross % US', data=df, color='black', size=8, alpha=0.7)

# Add labels and title
plt.xlabel('Genre')
plt.ylabel('Gross % US')
plt.title('Box Plot with Swarm Plot: Genre vs Gross % US')

plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 68.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 22.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 41.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
top6_studio=['Buena Vista Studios','Fox','Paramount Pictures','Sony','Universal','WB']
studio_df=df[df.Studio.isin(top6_studio)]

genre_filter =['action','adventure','animation','comedy','drama']
genre_df=studio_df[studio_df.Genre.isin(genre_filter)]
ax=sns.boxplot(data=genre_df,x='Genre',y='Gross % US',orient='v',color='lightgray')
plt.setp(ax.artists,alpha=0.5)
sns.stripplot(x='Genre',y='Gross % US',data=genre_df,hue='Studio',jitter=True,size=6,alpha=0.7)
ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel('Gross % US',fontsize=20)
ax.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
cor_mat=df.corr()
fig = plt.figure(figsize=(15,7))
sns.heatmap(cor_mat,annot=True)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22268\2047984449.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_mat=df.corr()

# %%
print(cor_mat['Profit%'].sort_values(ascending=False), '\n')
# Out:
# Profit%             1.000000
# Gross % US          0.084881
# IMDb Rating         0.077253
# US ($mill)          0.050342
# MovieLens Rating    0.049759
# Runtime (min)      -0.042088
# Overseas%          -0.084881
# Budget ($mill)     -0.298632
# Name: Profit%, dtype: float64

# %%
# Group the dataset by genre and director, then calculate the mean IMDb rating for each combination
genre_director_rating = df.groupby(['Genre', 'Director'])['IMDb Rating'].mean().reset_index()

# Find the top director for each genre based on IMDb rating
top_directors_by_genre_rating = genre_director_rating.loc[genre_director_rating.groupby('Genre')['IMDb Rating'].idxmax()]

# Get the list of 15 distinct colors from a seaborn color palette
colors = sns.color_palette('tab20', n_colors=15)

# Create a dictionary mapping each genre to its corresponding color
genre_color_map = dict(zip(genre_director_rating['Genre'].unique(), colors))

# Create a grouped bar plot with unique colors for each genre
plt.figure(figsize=(12, 8))
for genre, director, rating in zip(top_directors_by_genre_rating['Genre'], top_directors_by_genre_rating['Director'], top_directors_by_genre_rating['IMDb Rating']):
    bar = plt.bar(genre, rating, label=director, color=genre_color_map[genre])
    plt.text(bar[0].get_x() + bar[0].get_width() / 2, bar[0].get_height() + 0.01, f'{rating:.2f}', ha='center', va='bottom')

# Add labels and legend
plt.title('Top Director for Each Genre Based on IMDb Rating')
plt.xlabel('Genre')
plt.ylabel('Average IMDb Rating')
plt.xticks(rotation=45)
plt.legend(title='Director', bbox_to_anchor=(1, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22268\1096957171.py:25: UserWarning: Glyph 136 (\x88) missing from current font.
#   plt.tight_layout()
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 136 (\x88) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Filter action movies
action_movies = df[df['Genre'] == 'action'].sort_values(by='IMDb Rating', ascending=False).head(5)

# Plotting top 5 action movies
plt.figure(figsize=(10, 6))
bars = plt.barh(action_movies['Movie Title'], action_movies['IMDb Rating'], color='skyblue')
plt.xlabel('IMDb Rating')
plt.ylabel('Movie Title')
plt.title('Top 5 Action Movies Based on IMDb Rating')
plt.gca().invert_yaxis()  # Invert y-axis to display the highest rating at the top

# Annotate the IMDb rating values on the plot
for bar, rating in zip(bars, action_movies['IMDb Rating']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, str(round(rating, 2)), ha='left', va='center')

plt.tight_layout()
plt.show()

# %%
# Count the number of movies for each director
director_counts = df['Director'].value_counts().head(10)

# Plotting
plt.figure(figsize=(10, 6))
director_counts.plot(kind='bar', color='skyblue')
plt.title('Top 10 Directors with Highest Number of Movies')
plt.xlabel('Director')
plt.ylabel('Number of Movies')

# Set y-tick labels to integer values
plt.yticks(range(int(director_counts.max()) + 1))

plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Assuming df_content is your dataset containing Movie Title, IMDb Rating, MovieLens Rating, and Genre
# Feature selection
content_features = df[['IMDb Rating', 'MovieLens Rating', 'Genre']]

# Fill any missing values (you may need to handle missing values more appropriately)
content_features = content_features.fillna(0)

# Combine features into a single column for text processing
content_features['combined_features'] = content_features.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Initialize the TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# Fit and transform the data
tfidf_matrix = tfidf_vectorizer.fit_transform(content_features['combined_features'])

# User input
user_input_imdb = float(input("Enter IMDb rating: "))
user_input_movielens = float(input("Enter MovieLens rating: "))
user_input_genre = input("Enter movie genre: ")

# Transform user input into a format compatible with the model
user_input_features = [user_input_imdb, user_input_movielens, user_input_genre]
user_input_combined = ' '.join(map(str, user_input_features))

# Transform user input into a TF-IDF vector
user_input_tfidf = tfidf_vectorizer.transform([user_input_combined])

# Compute cosine similarity between user input and movie features
cosine_similarities = linear_kernel(user_input_tfidf, tfidf_matrix).flatten()

# Get indices of the top N similar movies
top_n_indices = cosine_similarities.argsort()[:-6:-1]

# Print recommended movies
print("Recommended Movies:")
for index in top_n_indices:
    print(df.iloc[index]['Movie Title'])
# Out:
# Enter IMDb rating: 7
# Enter MovieLens rating: 5
# Enter movie genre: action
# Recommended Movies:
# The Bourne Identity
# The Last Samurai
# Independence Day
# The Lord of the Rings: The Two Towers
# Non-Stop
